# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Zulfikar-CTRL-z/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I want to work on search performance and understand which content-level signals are associated with changes in organic search impressions. I chose this lane because a drop in impressions can indicate that a page needs attention, and finding useful signals could help teams prioritize which content to investigate first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is whether a content item should be prioritized for further investigation when its search impressions decline. An SEO or content team could use the analysis to decide which pages deserve attention first. A wrong recommendation could waste time on a page that does not need action, while missing a real decline could delay useful content improvements.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Here is a quick analysis of the starter dataset to establish the baseline numbers for our content refresh lane:

# %%
import pandas as pd
try:
  df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
except FileNotFoundError:
  df = pd.read_csv('https://raw.githubusercontent.com/Zulfikar-CTRL-z/FlyRank-Internship/main/data/raw/content_refresh_anonymized.csv')
total_pages = len(df)
declining_pages = (df['trend_direction'] == 'down').sum()
pct_declining = (declining_pages / total_pages) * 100
print(f"Total pages in sample: {total_pages}")
print(f"Pages with declining performance: {declining_pages}")
print(f"Percentage of declining pages: {pct_declining:.2f}%")
# Out:
# Total pages in sample: 30000
# Pages with declining performance: 16262
# Percentage of declining pages: 54.21%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My analysis will describe observed relationships in the available search-performance data and provide directional decision-support for prioritizing content investigation. I can measure associations between features and search performance, but I cannot claim that one feature causes another outcome. I also cannot claim that the model predicts Google rankings or future Google behavior.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
